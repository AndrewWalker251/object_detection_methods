# %% [markdown]
# # YOLOv5
#
# The intention of this notebook is to provide the pipeline to quickly implement easily available YOLOv5 implementations on your own problem datasets.
#
# ## YOLOv5 How it works
#
# section explaining how YOLOv5 works.
